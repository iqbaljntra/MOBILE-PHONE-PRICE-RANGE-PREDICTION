# %% [markdown]
# # P1M2 MODEL INFERANCE
#
# ### Name : Iqbal Janitra
# ### Batch : 003

# %%
import pandas as pd
import numpy as np
import joblib

# %% [markdown]
# # MODEL LOAD

# %%
with open('all_process', 'rb') as file_1:
  all_process= joblib.load(file_1)

# %% [markdown]
# ### Make Random Data

# %%
random = np.random.default_rng(seed=2895)
sample type = random.integers(501, 1998, size=30)
v1 =  random.integers(500, 1960, size=30)
v2 =  random.integers(500, 1998, size=30)
v3 = random.integers(256, 3998, size=30)
v4 = random.choice([1,0], size=30)
v5 = random.choice([1,0], size=30)
v6 = random.choice([1,0], size=30) = random.choice([2, 3, 5, 6, 1, 8, 4, 7], size=30)
v7 = random.choice([4, 11, 16, 21,  2], size=30)
 = random.choice([4, 11, 16, 20,  2], size=30)
data_inf = pd.DataFrame({'battery_power' : battery_power, 'px_height' : px_height, 'px_width' : px_width, 'ram':ram,
                        'four_g' : four_g, 'touch_screen' : touch_screen, 'dual_sim' : dual_sim, 'n_cores' : n_cores, 'primary_camera' : primary_camera,
                         'front_camera' : front_camera})
data_inf
# Out:
#     battery_power  px_height  px_width   ram  four_g  touch_screen  dual_sim  \
# 0             567       1188      1364  2934       0             0         0
# 1            1986        555      1684  2591       0             0         0
# 2            1256        826       581  3477       1             1         0
# 3             609       1232      1978  2364       1             0         0
# 4            1015       1102      1228  2088       0             1         0
# 5            1512       1626       831  3962       0             0         1
# 6             674        932      1129  1445       0             1         0
# 7            1611        970      1653  1887       0             1         1
# 8            1300       1262      1117  1105       1             0         1
# 9            1733        767      1054   763       0             0         0
# 10           1669        975       920  2404       0             0         0
# ...

# %% [markdown]
# # Make a final model prediction

# %%
final_predict = all_process.predict(data_inf)
final_predict
# Out:
# array([2, 3, 3, 2, 1, 3, 0, 2, 1, 0, 2, 3, 0, 3, 3, 3, 2, 2, 1, 3, 3, 3,
#        1, 1, 3, 0, 3, 3, 1, 3])

# %%
predict = pd.DataFrame(final_predict, columns=["Price Range Prediction"])
predict
# Out:
#     Price Range Prediction
# 0                        2
# 1                        3
# 2                        3
# 3                        2
# 4                        1
# 5                        3
# 6                        0
# 7                        2
# 8                        1
# 9                        0
# 10                       2
# 11                       3
# 12                       0
# 13                       3
# 14                       3
# 15                       3
# 16                       2
# 17                       2
# 18                       1
# 19                       3
# 20                       3
# 21                       3
# 22                       1
# 23                       1
# 24                       3
# 25                       0
# 26                       3
# 27                       3
# 28                       1
# 29                       3
